# %% [markdown]
# # **Imports**

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# ------------------------------------------
# desabilita warnings
# ------------------------------------------
import warnings
warnings.filterwarnings('ignore')

# %%
# ------------------------------------------
# bibliotecas principais
# ------------------------------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# %%
# Instala a biblioteca SHAP
# !pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (569 kB)
#      |████████████████████████████████| 569 kB 8.8 MB/s
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.56.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.21.6)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.64.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.5)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.5.0)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap) (21.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.7.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->shap) (4.12.0)
# Requirement already satisfied: setuptools<60 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (3.1.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
df = pd.read_csv('/content/drive/Shareddrives/grupo4-rappi-hour/bases-rappi/df-oficial.csv')

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157470 entries, 0 to 157469
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   IS_ACTIVE                   157470 non-null  int64
#  1   AUTO_ACEITE                 157470 non-null  int64
#  2   COOKING_TIME_MEDIO          157470 non-null  float64
#  3   ITENS_MEDIO                 157470 non-null  float64
#  4   DISTANCE_TO_USER            157470 non-null  float64
#  5   CANCELS_OPS_RT              157470 non-null  float64
#  6   ACCEPTANCE_RATE             157470 non-null  float64
#  7   PUNISHMENT_MINUTES          157470 non-null  float64
#  8   TEMPORARY_BLOCKS            157470 non-null  float64
#  9   WARNINGS                    157470 non-null  float64
#  10  ORDERS_PER_HOURS_CONNECTED  157470 non-null  float64
#  11  age-1st-qtile               157470 non-null  int64
#  12  age-2nd-qtile               157470 non-null  int64
#  13  age-3rd-qtile               157470 non-null  int64
#  14  age-4th-qtile               157470 non-null  int64
#  15  bicycle                     157470 non-null  int64
#  16  car                         157470 non-null  int64
#  17  cargo_van                   157470 non-null  int64
#  18  motorbike                   157470 non-null  int64
#  19  motorbike_trailer           157470 non-null  int64
#  20  neither                     157470 non-null  int64
#  21  total_earnings              157470 non-null  float64
#  22  incidents_na                157470 non-null  int64
#  23  incidents_1                 157470 non-null  int64
#  24  incidents_2                 157470 non-null  int64
#  25  incidents_3                 157470 non-null  int64
#  26  incidents_4                 157470 non-null  int64
#  27  incidents_5                 157470 non-null  int64
#  28  incidents_6                 157470 non-null  int64
#  29  incidents_7                 157470 non-null  int64
#  30  incidents_8                 157470 non-null  int64
#  31  incidents_9                 157470 non-null  int64
#  32  incidents_10                157470 non-null  int64
# dtypes: float64(10), int64(23)
# memory usage: 39.6 MB

# %% [markdown]
# ## Features / Target

# %%
x = df.drop(columns="IS_ACTIVE") # features
y = df["IS_ACTIVE"] # target

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size = 0.3, 
                                                    random_state = 1)

# %%
from sklearn.preprocessing import MinMaxScaler

# instaciando o objeto scaler
scaler = MinMaxScaler()

# fit + transform no conjunto de treino
# utiliza apenas o transform : fit exclusivo no conjunto de treino
x_train[list(x_train.columns)] = scaler.fit_transform(x_train[list(x_train.columns)])

# scaler no conjunto de teste
x_test[list(x_test.columns)] = scaler.transform(x_test[list(x_test.columns)])

# %%
y_train.squeeze()
# Out:
# 19778     2
# 96599     2
# 58231     2
# 11258     2
# 67121     2
#          ..
# 73349     2
# 109259    2
# 50057     2
# 5192      1
# 128037    2
# Name: IS_ACTIVE, Length: 110229, dtype: int64

# %%
y_true = y_test

# %% [markdown]
# ### **Models**

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# Instaciação do obj Algoritmo
logreg = LogisticRegression()
# Treino # x = Features, y = Label/Target
logreg.fit( x_train, y_train.squeeze() ) # squeeze() -> df para series
# Out:
# LogisticRegression()

# %%
print('Acuracidade (treino): ', logreg.score( x_train, y_train ))
print('Acuracidade (teste): ', logreg.score( x_test, y_test ))
# Out:
# Acuracidade (treino):  0.7195384154804997
# Acuracidade (teste):  0.7205181939417031

# %%
y_pred_logreg = logreg.predict(x_test)

# %%
cm_logreg = confusion_matrix(y_true, y_pred_logreg, normalize = 'true')
cm_logreg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-0d144c6d1212> in <module>
# ----> 1 cm_logreg = confusion_matrix(y_true, y_pred_logreg, normalize = 'true')
#       2 cm_logreg
#
# NameError: name 'y_true' is not defined

# %%
# versão visual mais bonita da matriz
disp_logreg = ConfusionMatrixDisplay(confusion_matrix=cm_logreg, 
                              display_labels=logreg.classes_)

disp_logreg.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred_logreg))

# %%
importance = logreg.coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()

# %% [markdown]
# ## Adaboost

# %%
#from sklearn.ensemble import AdaBoostClassifier

# Instaciação do obj Algoritmo
#adaboost = AdaBoostClassifier()
# Treino # x = Features, y = Label/Target
#adaboost.fit( x_train, y_train.squeeze() ) # squeeze() -> df para series

# %%
#print('Acuracidade (treino): ', adaboost.score( x_train, y_train ))
#print('Acuracidade (teste): ', adaboost.score( x_test, y_test ))

# %%
#y_pred_adaboost = adaboost.predict(x_test)

# %%
#cm_adaboost = confusion_matrix(y_true, y_pred_adaboost, normalize = 'true')
#cm_adaboost

# %%
# versão visual mais bonita da matriz
#disp_adaboost = ConfusionMatrixDisplay(confusion_matrix=cm_adaboost, 
#                              display_labels=adaboost.classes_)

#disp_adaboost.plot()
#plt.show()

# %%
#print(classification_report(y_test, y_pred_adaboost))

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Instaciação do obj Algoritmo
ranfor = RandomForestClassifier()
# Treino # x = Features, y = Label/Target
ranfor.fit( x_train, y_train ) # squeeze() -> df para series
# Out:
# RandomForestClassifier()

# %%
print('Acuracidade (treino): ', ranfor.score( x_train, y_train ))
print('Acuracidade (teste): ', ranfor.score( x_test, y_test ))
# Out:
# Acuracidade (treino):  0.9999909279772111
# Acuracidade (teste):  0.8557608856713448

# %%
y_pred_ranfor = ranfor.predict(x_test)

# %%
cm_ranfor = confusion_matrix(y_true, y_pred_ranfor, normalize = 'true')
cm_ranfor
# Out:
# array([[9.92496589e-01, 1.70532060e-03, 5.79809004e-03],
#        [1.76195930e-04, 5.33873668e-01, 4.65950137e-01],
#        [0.00000000e+00, 4.93239193e-02, 9.50676081e-01]])

# %%
# versão visual mais bonita da matriz
disp_ranfor = ConfusionMatrixDisplay(confusion_matrix=cm_ranfor, 
                              display_labels=ranfor.classes_)

disp_ranfor.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred_ranfor))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5864
#            1       0.80      0.53      0.64     11351
#            2       0.84      0.95      0.89     30026
#
#     accuracy                           0.86     47241
#    macro avg       0.88      0.83      0.84     47241
# weighted avg       0.85      0.86      0.85     47241

# %% [markdown]
# ## SGD

# %%
#from sklearn.linear_model import SGDClassifier

# Instaciação do obj Algoritmo
#sgd = SGDClassifier()
# Treino # x = Features, y = Label/Target
#sgd.fit( x_train, y_train.squeeze() ) # squeeze() -> df para series

# %%
#print('Acuracidade (treino): ', sgd.score( x_train, y_train ))
#print('Acuracidade (teste): ', sgd.score( x_test, y_test ))

# %%
#y_pred_sgd = sgd.predict(x_test)

# %%
#cm_sgd = confusion_matrix(y_true, y_pred_sgd, normalize = 'true')
#cm_sgd

# %%
# versão visual mais bonita da matriz
#disp_sgd = ConfusionMatrixDisplay(confusion_matrix=cm_sgd, 
#                              display_labels=sgd.classes_)

#disp_sgd.plot()
#plt.show()

# %%
#print(classification_report(y_test, y_pred_sgd))

# %% [markdown]
# ## SVM

# %%
from sklearn import svm

# instaciando obj do algoritmo
svm = svm.SVC()

# treino 
# x = features
# y = label/target
# squeeze() -> df para series
svm.fit(x_train, y_train.squeeze())
# Out:
# SVC()

# %%
print('Acuracidade (treino): ', svm.score( x_train, y_train ))
print('Acuracidade (teste): ', svm.score( x_test, y_test ))
# Out:
# Acuracidade (treino):  0.7305881392374057
# Acuracidade (teste):  0.7299168095510256

# %%
y_pred_svm = svm.predict(x_test)

# %%
cm_svm = confusion_matrix(y_test, y_pred_svm, normalize = 'true')
cm_svm
# Out:
# array([[0.87124829, 0.00153479, 0.12721692],
#        [0.02757466, 0.13699234, 0.835433  ],
#        [0.04442816, 0.02910811, 0.92646373]])

# %%
disp_svm = ConfusionMatrixDisplay(confusion_matrix=cm_svm, 
                             display_labels=svm.classes_)

disp_svm.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      5864
#            1       0.64      0.14      0.23     11351
#            2       0.73      0.93      0.82     30026
#
#     accuracy                           0.73     47241
#    macro avg       0.71      0.64      0.62     47241
# weighted avg       0.71      0.73      0.67     47241

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# Instaciação do obj Algoritmo
knn = KNeighborsClassifier(n_neighbors=5)
# Treino # x = Features, y = Label/Target
knn.fit( x_train, y_train.squeeze() ) # squeeze() -> df para series
# Out:
# KNeighborsClassifier()

# %%
print('Acuracidade (treino): ', knn.score( x_train, y_train ))
print('Acuracidade (teste): ', knn.score( x_test, y_test ))
# Out:
# Acuracidade (treino):  0.8242839906013844
# Acuracidade (teste):  0.7529476514045004

# %%
y_pred_knn = knn.predict(x_test)

# %%
cm_knn = confusion_matrix(y_true, y_pred_knn, normalize = 'true')
cm_knn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-85a0feac372a> in <module>
# ----> 1 cm_knn = confusion_matrix(y_true, y_pred_knn, normalize = 'true')
#       2 cm_knn
#
# NameError: name 'y_true' is not defined

# %%
# versão visual mais bonita da matriz
disp_knn = ConfusionMatrixDisplay(confusion_matrix=cm_knn, 
                              display_labels=knn.classes_)

disp_knn.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred_knn))

# %% [markdown]
# ## LGBM

# %%
import lightgbm as lgb

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42)
# Criando o modelo

lgb = lgb.LGBMClassifier()

lgb.fit(x_train, y_train)
# Out:
# LGBMClassifier()

# %%
print('Acuracidade (treino): ', lgb.score( x_train, y_train ))
print('Acuracidade (teste): ', lgb.score( x_test, y_test ))
# Out:
# Acuracidade (treino):  0.8724201435194006
# Acuracidade (teste):  0.8654981901314536

# %%
y_pred_lgb = lgb.predict(x_test)

# %%
cm_lgb = confusion_matrix(y_true, y_pred_lgb, normalize = 'true')
cm_lgb
# Out:
# array([[0.12141883, 0.18656207, 0.6920191 ],
#        [0.11769888, 0.18923443, 0.69306669],
#        [0.12116166, 0.18487311, 0.69396523]])

# %%
# versão visual mais bonita da matriz
disp_lgb = ConfusionMatrixDisplay(confusion_matrix=cm_lgb, 
                            display_labels=lgb.classes_)

disp_lgb.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred_lgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5710
#            1       0.79      0.61      0.69     11439
#            2       0.86      0.94      0.90     30092
#
#     accuracy                           0.87     47241
#    macro avg       0.88      0.85      0.86     47241
# weighted avg       0.86      0.87      0.86     47241

# %% [markdown]
# #

# %% [markdown]
# **Mudança nos parâmetros**

# %%
from sklearn.model_selection import GridSearchCV

model = lgb 

# Cria o GridSearchCV
parameters = {
    'boosting_type':['gbdt','dart','goss','rf'], 
    'num_leaves':[42,31],
    'max_depth':range(-3,0),
    'n_estimators':[80,100,200,120]
    }
modelGS = GridSearchCV(model, parameters)

# Treina os modelos e guarda na variável modelGS o melhor modelo
modelGS.fit(x_train, y_train)
modelGS.best_params_

#print('Acuracidade (treino): ', lgb.score( x_train, y_train ))
#print('Acuracidade (teste): ', lgb.score( x_test, y_test ))
#,
  #  'objective':'multiclass',
 #   '':0,
 #   '':0,
 #   '':0

# %%
print('Acuracidade (treino): ', modelGS.score( x_train, y_train ))
print('Acuracidade (teste): ', modelGS.score( x_test, y_test ))

# %%
import lightgbm as lgb
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42)
# Criando o modelo

BestModel = lgb.LGBMClassifier(objective='multiclass',num_leaves=42,max_depth=-3,n_estimators=200)

BestModel.fit(x_train, y_train)
# Out:
# LGBMClassifier(max_depth=-3, n_estimators=200, num_leaves=42,
#                objective='multiclass')

# %%
y_pred_BestModel = BestModel.predict(x_test)
cm_BestModel = confusion_matrix(y_true, y_pred_BestModel, normalize = 'true')
modelGS = confusion_matrix(y_true, y_pred_BestModel, normalize = 'true')
cm_BestModel
# Out:
# array([[0.12141883, 0.19218963, 0.68639154],
#        [0.11769888, 0.19275835, 0.68954277],
#        [0.12112836, 0.19043496, 0.68843669]])

# %%
# versão visual da matriz
disp_BestModel = ConfusionMatrixDisplay(confusion_matrix=cm_BestModel, 
                            display_labels=BestModel.classes_)

disp_BestModel.plot()
plt.show()

# %%
print('Acuracidade (treino): ', BestModel.score( x_train, y_train ))
print('Acuracidade (teste): ', BestModel.score( x_test, y_test ))
# Out:
# Acuracidade (treino):  0.8857106569051701
# Acuracidade (teste):  0.8689697508520141

# %% [markdown]
# # **Cluster Resample**

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=13)
x_resampled, y_resampled = rus.fit_resample(x, y)

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x, y, 
                                                    test_size = 0.3, 
                                                    random_state = 8)

# %%
# Instaciando o objeto scaler
scaler = MinMaxScaler()

# Fit + transform no conjunto de treino
# Utilizando explicitamente as colunas de ambos os lados força que o
# resultado da normalização ainda seja o dataframe (muito mais facil de manipular) e não um numpy array
x_train1[list(x_train1.columns)] = scaler.fit_transform(x_train1[list(x_train1.columns)])

# Agora utilizando o scaler no conjunto de teste
# Utilizar apenas o transform, pois fit é só no conjunto de treino,]
# o conjunto de teste é utilizado para medir a capacidade de generalização do modelo no mundo real (dados não vistos)
# então faz sentido que a mesma normalização treinada e submetida ao conjunto de treino seja apenas aplicada no de teste
x_test1[list(x_test1.columns)] = scaler.transform(x_test1[list(x_test1.columns)])

# %%
y_train1.squeeze()
# Out:
# 46267     2
# 141493    0
# 126779    2
# 146212    0
# 62926     2
#          ..
# 141448    0
# 62426     1
# 149489    0
# 25940     1
# 70083     2
# Name: IS_ACTIVE, Length: 110229, dtype: int64

# %%
y_true1 = y_test1

# %% [markdown]
# ## Logistic Regression

# %%
logreg.fit( x_train1, y_train1.squeeze() ) # squeeze() -> df para series
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-b3a8b3873ac4> in <module>
# ----> 1 logreg.fit( x_train1, y_train1.squeeze() ) # squeeze() -> df para series
#
# NameError: name 'logreg' is not defined

# %%
print('Acuracidade (treino): ', logreg.score( x_train1, y_train1 ))
print('Acuracidade (teste): ', logreg.score( x_test1, y_test1 ))

# %%
y_pred_logreg = logreg.predict(x_test1)

# %%
cm_logreg = confusion_matrix(y_true1, y_pred_logreg, normalize = 'true')
cm_logreg

# %%
# versão visual mais bonita da matriz
disp_logreg = ConfusionMatrixDisplay(confusion_matrix=cm_logreg, 
                              display_labels=logreg.classes_)

disp_logreg.plot()
plt.show()

# %%
print(classification_report(y_test1, y_pred_logreg))

# %%
importance = logreg.coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x_resampled for x_resampled in range(len(importance))], importance)
plt.show()

# %% [markdown]
# ## Adaboost

# %%
#adaboost.fit( x_train1, y_train1.squeeze() ) # squeeze() -> df para series

# %%
#print('Acuracidade (treino): ', adaboost.score( x_train1, y_train1 ))
#print('Acuracidade (teste): ', adaboost.score( x_test1, y_test1 ))

# %%
#y_pred_adaboost = adaboost.predict(x_test1)

# %%
#cm_adaboost = confusion_matrix(y_true1, y_pred_adaboost, normalize = 'true')
#cm_adaboost

# %%
# versão visual mais bonita da matriz
#disp_adaboost = ConfusionMatrixDisplay(confusion_matrix=cm_adaboost, 
#                              display_labels=adaboost.classes_)

#disp_adaboost.plot()
#plt.show()

# %%
#print(classification_report(y_test1, y_pred_adaboost))

# %% [markdown]
# ## Random Forest

# %%
ranfor.fit( x_train1, y_train1 ) # squeeze() -> df para series

# %%
print('Acuracidade (treino): ', ranfor.score( x_train1, y_train1 ))
print('Acuracidade (teste): ', ranfor.score( x_test1, y_test1 ))

# %%
y_pred_ranfor = ranfor.predict(x_test1)

# %%
cm_ranfor = confusion_matrix(y_true1, y_pred_ranfor, normalize = 'true')
cm_ranfor

# %%
# versão visual mais bonita da matriz
disp_ranfor = ConfusionMatrixDisplay(confusion_matrix=cm_ranfor, 
                             display_labels=ranfor.classes_)

disp_ranfor.plot()
plt.show()

# %%
print(classification_report(y_test1, y_pred_ranfor))

# %% [markdown]
# ## SGD

# %%
#sgd.fit( x_train1, y_train1.squeeze() ) # squeeze() -> df para series

# %%
#print('Acuracidade (treino): ', sgd.score( x_train1, y_train1 ))
#print('Acuracidade (teste): ', sgd.score( x_test1, y_test1 ))

# %%
#y_pred_sgd = sgd.predict(x_test1)

# %%
#cm_sgd = confusion_matrix(y_true1, y_pred_sgd, normalize = 'true')
#cm_sgd

# %%
# versão visual mais bonita da matriz
#disp_sgd = ConfusionMatrixDisplay(confusion_matrix=cm_sgd, 
#                              display_labels=sgd.classes_)

#disp_sgd.plot()
#plt.show()

# %%
#print(classification_report(y_test1, y_pred_sgd))

# %% [markdown]
# ## LGB

# %%
BestModel.fit(x_train1, y_train1)
# Out:
# LGBMClassifier(max_depth=-3, n_estimators=200, num_leaves=42,
#                objective='multiclass')

# %%
print('Acuracidade (treino): ', BestModel.score( x_train1, y_train1 ))
print('Acuracidade (teste): ', BestModel.score( x_test1, y_test1 ))
# Out:
# Acuracidade (treino):  0.8867448675031072
# Acuracidade (teste):  0.8694142799686713

# %%
y_pred_BestModel = BestModel.predict(x_test1)

# %%
cm_BestModel = confusion_matrix(y_true1, y_pred_BestModel, normalize = 'true')
cm_BestModel
# Out:
# array([[9.92317094e-01, 2.26994936e-03, 5.41295617e-03],
#        [1.75916967e-04, 6.23537690e-01, 3.76286393e-01],
#        [1.99037983e-04, 6.10051418e-02, 9.38795820e-01]])

# %%
# versão visual mais bonita da matriz
disp_BestModel = ConfusionMatrixDisplay(confusion_matrix=cm_BestModel, 
                              display_labels=BestModel.classes_)

disp_BestModel.plot()
plt.show()

# %%
BestModel.predict(x_test1)
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
predicao = BestModel.predict_proba(x_test1)

# %%
x_test1.shape
# Out:
# (47241, 32)

# %% [markdown]
# ## **Rank da possibilidade de dar Churn.**
#
# Para nosso projeto 0 indica um Churn definitivo, 1 indica os RTs com alta constância e o 2 os RTs com baixa constância.

# %%
resultado_Rotulado = []
casosAparte = []
rank = {
    1:"N_Churn",
    2:"PN_Churn",
    3:"Incerto",
    4:"P_Churn",
    5:"Churn"
    }

predicao_df = pd.DataFrame (predicao, columns = [['Churn','RT_Inconsistente','Nao_Churn']])

# %%
predicao_df.max()
# Out:
# Churn               0.999996
# RT_Inconsistente    0.999794
# Nao_Churn           0.998830
# dtype: float64

# %%
predicao_df.mean()
# Out:
# Churn               0.120566
# RT_Inconsistente    0.240611
# Nao_Churn           0.638823
# dtype: float64

# %%
predicao_df.min()
# Out:
# Churn               7.224622e-07
# RT_Inconsistente    1.846827e-06
# Nao_Churn           9.015956e-07
# dtype: float64

# %%
from numpy.lib.function_base import append


for i in predicao:
  if i[0] > 0.7:
    resultado_Rotulado.append("Churn")
  elif i[2] > 0.7:
    resultado_Rotulado.append("RT_Inconsistente")
  elif i[1] >= 0.7:
    resultado_Rotulado.append("Nao_Churn")
  elif i[2] > i[1]:
    resultado_Rotulado.append("Provavel_Churn")
  elif i[1] > i[2]:
    resultado_Rotulado.append("Provavel_Nao_Churn")
  else:
    casosAparte.append(i)

# %%
resultado_Rotulado
# Out:
# []

# %%
resultado_column = pd.DataFrame (resultado_Rotulado, columns = ['Status_RT'])

# %%
resultado_column.shape
# Out:
# (47241, 1)

# %%
resultado_column
# Out:
#               Status_RT
# 0      RT_Inconsistente
# 1        Provavel_Churn
# 2      RT_Inconsistente
# 3      RT_Inconsistente
# 4      RT_Inconsistente
# ...                 ...
# 47236  RT_Inconsistente
# 47237  RT_Inconsistente
# 47238  RT_Inconsistente
# 47239    Provavel_Churn
# 47240  RT_Inconsistente
#
# [47241 rows x 1 columns]

# %%
resultado_column.value_counts()
# Out:
# Status_RT
# RT_Inconsistente      28253
# Churn                  5691
# Nao_Churn              5461
# Provavel_Churn         4356
# Provavel_Nao_Churn     3480
# dtype: int64

# %%
casosAparte_colum = pd.DataFrame (casosAparte, columns = ['0','1','2'])

# %%
casosAparte_colum

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# Instaciação do obj Algoritmo
knn = KNeighborsClassifier(n_neighbors= 21)
# Treino # x = Features, y = Label/Target
knn.fit( x_train1, y_train1.squeeze() ) # squeeze() -> df para series
# Out:
# KNeighborsClassifier(n_neighbors=21)

# %%
print('Acuracidade (treino): ', knn.score( x_train1, y_train1 ))
print('Acuracidade (teste): ', knn.score( x_test1, y_test1 ))
# Out:
# Acuracidade (treino):  0.7773453446915058
# Acuracidade (teste):  0.7603141339091044

# %%
y_pred_knn = knn.predict(x_test1)

# %%
cm_knn = confusion_matrix(y_true1, y_pred_knn, normalize = 'true')
cm_knn
# Out:
# array([[0.94953728, 0.00541296, 0.04504976],
#        [0.02005453, 0.2959803 , 0.68396517],
#        [0.02514513, 0.07536905, 0.89948582]])

# %%
# versão visual mais bonita da matriz
disp_knn = ConfusionMatrixDisplay(confusion_matrix=cm_knn, 
                              display_labels=knn.classes_)

disp_knn.plot()
plt.show()

# %%
print(classification_report(y_test1, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      5727
#            1       0.59      0.30      0.40     11369
#            2       0.77      0.90      0.83     30145
#
#     accuracy                           0.76     47241
#    macro avg       0.74      0.72      0.71     47241
# weighted avg       0.74      0.76      0.73     47241

# %% [markdown]
# ## SVM

# %%
#svm.fit( x_train1, y_train1.squeeze() ) # squeeze() -> df para series

# %%
#print('Acuracidade (treino): ', svm.score( x_train1, y_train1 ))
#print('Acuracidade (teste): ', svm.score( x_test1, y_test1 ))

# %%
#y_pred_svm = svm.predict(x_test1)

# %%
#cm_svm = confusion_matrix(y_true1, y_pred_svm, normalize = 'true')
#cm_svm

# %%
# versão visual mais bonita da matriz
#disp_svm = ConfusionMatrixDisplay(confusion_matrix=cm_svm, 
#                              display_labels=svm.classes_)

#disp_svm.plot()
#plt.show()

# %%
#print(classification_report(y_test1, y_pred_svm))
